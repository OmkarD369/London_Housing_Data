# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\omkar\Downloads\London Housing Dataset.csv')

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
data.count()
# Out:
# date             13549
# area             13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# dtype: int64

# %%
data.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %%
import matplotlib.pyplot as pl

# %%
data.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
data['date'] = pd.to_datetime(data['date'], format='%d/%m/%Y') # Always remember to give format for changing datatype of date into datetime

# %%
data.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %%
data['Year'] = data['date'].dt.year

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-01-02  city of london          82203  E09000001          7.0
# 2     1995-01-03  city of london          79121  E09000001         14.0
# 3     1995-01-04  city of london          77101  E09000001          7.0
# 4     1995-01-05  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-01-09         england         249942  E92000001      64605.0
# 13545 2019-01-10         england         249376  E92000001      68677.0
# 13546 2019-01-11         england         248515  E92000001      67814.0
# 13547 2019-01-12         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  Year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %%
data['month'] = data['date'].dt.month

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-01-02  city of london          82203  E09000001          7.0
# 2     1995-01-03  city of london          79121  E09000001         14.0
# 3     1995-01-04  city of london          77101  E09000001          7.0
# 4     1995-01-05  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-01-09         england         249942  E92000001      64605.0
# 13545 2019-01-10         england         249376  E92000001      68677.0
# 13546 2019-01-11         england         248515  E92000001      67814.0
# 13547 2019-01-12         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  Year  month
# 0               NaN  1995      1
# 1               NaN  1995      1
# ...

# %%
data.insert(2,'Month', data['date'].dt.month)

# %%
data
# Out:
#             date            area  Month  average_price       code  \
# 0     1995-01-01  city of london      1          91449  E09000001
# 1     1995-01-02  city of london      1          82203  E09000001
# 2     1995-01-03  city of london      1          79121  E09000001
# 3     1995-01-04  city of london      1          77101  E09000001
# 4     1995-01-05  city of london      1          84409  E09000001
# ...          ...             ...    ...            ...        ...
# 13544 2019-01-09         england      1         249942  E92000001
# 13545 2019-01-10         england      1         249376  E92000001
# 13546 2019-01-11         england      1         248515  E92000001
# 13547 2019-01-12         england      1         250410  E92000001
# 13548 2020-01-01         england      1         247355  E92000001
#
#        houses_sold  no_of_crimes  Year  month
# 0             17.0           NaN  1995      1
# 1              7.0           NaN  1995      1
# ...

# %%
data.drop(['Month','month','Year'], inplace= True, axis = 1)

# %% [markdown]
# Note: when using the drop method in Pandas, you need to specify the axis parameter to indicate whether you want to drop labels from the index (rows) or columns.

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-01-02  city of london          82203  E09000001          7.0
# 2     1995-01-03  city of london          79121  E09000001         14.0
# 3     1995-01-04  city of london          77101  E09000001          7.0
# 4     1995-01-05  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-01-09         england         249942  E92000001      64605.0
# 13545 2019-01-10         england         249376  E92000001      68677.0
# 13546 2019-01-11         england         248515  E92000001      67814.0
# 13547 2019-01-12         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
(data['no_of_crimes'] == 0).sum()
# Out:
# 104

# %%
data.groupby('area').max('no_of_crimes')
# Out:
#                         average_price  houses_sold  no_of_crimes
# area
# barking and dagenham           305882        435.0        2049.0
# barnet                         549401        891.0        2893.0
# bexley                         347531        633.0        1914.0
# brent                          519754        542.0        2937.0
# bromley                        449293        870.0        2637.0
# camden                         881212        446.0        4558.0
# city of london                 939912        104.0          10.0
# croydon                        378859        916.0        3263.0
# ealing                         489687        678.0        3401.0
# east midlands                  196534      12191.0           NaN
# east of england                294035      15547.0           NaN
# enfield                        404393        763.0        2798.0
# england                        250410     132163.0           NaN
# ...

# %%
data = data.groupby('area')

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-01-02  city of london          82203  E09000001          7.0
# 2     1995-01-03  city of london          79121  E09000001         14.0
# 3     1995-01-04  city of london          77101  E09000001          7.0
# 4     1995-01-05  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-01-09         england         249942  E92000001      64605.0
# 13545 2019-01-10         england         249376  E92000001      68677.0
# 13546 2019-01-11         england         248515  E92000001      67814.0
# 13547 2019-01-12         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
df1 = data[data['area'] == 'england']

# %%
df1
# Out:
#             date     area  average_price       code  houses_sold  no_of_crimes
# 13248 1995-01-01  england          53203  E92000001      47639.0           NaN
# 13249 1995-01-02  england          53096  E92000001      47880.0           NaN
# 13250 1995-01-03  england          53201  E92000001      67025.0           NaN
# 13251 1995-01-04  england          53591  E92000001      56925.0           NaN
# 13252 1995-01-05  england          53678  E92000001      64192.0           NaN
# ...          ...      ...            ...        ...          ...           ...
# 13544 2019-01-09  england         249942  E92000001      64605.0           NaN
# 13545 2019-01-10  england         249376  E92000001      68677.0           NaN
# 13546 2019-01-11  england         248515  E92000001      67814.0           NaN
# 13547 2019-01-12  england         250410  E92000001          NaN           NaN
# 13548 2020-01-01  england         247355  E92000001          NaN           NaN
#
# [301 rows x 6 columns]

# %%
data['year'] = data['date'].dt.year

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-01-02  city of london          82203  E09000001          7.0
# 2     1995-01-03  city of london          79121  E09000001         14.0
# 3     1995-01-04  city of london          77101  E09000001          7.0
# 4     1995-01-05  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-01-09         england         249942  E92000001      64605.0
# 13545 2019-01-10         england         249376  E92000001      68677.0
# 13546 2019-01-11         england         248515  E92000001      67814.0
# 13547 2019-01-12         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %%
df1 = data[data['area'] == 'england']

# %%
df1
# Out:
#             date     area  average_price       code  houses_sold  \
# 13248 1995-01-01  england          53203  E92000001      47639.0
# 13249 1995-01-02  england          53096  E92000001      47880.0
# 13250 1995-01-03  england          53201  E92000001      67025.0
# 13251 1995-01-04  england          53591  E92000001      56925.0
# 13252 1995-01-05  england          53678  E92000001      64192.0
# ...          ...      ...            ...        ...          ...
# 13544 2019-01-09  england         249942  E92000001      64605.0
# 13545 2019-01-10  england         249376  E92000001      68677.0
# 13546 2019-01-11  england         248515  E92000001      67814.0
# 13547 2019-01-12  england         250410  E92000001          NaN
# 13548 2020-01-01  england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 13248           NaN  1995
# 13249           NaN  1995
# 13250           NaN  1995
# 13251           NaN  1995
# 13252           NaN  1995
# ...

# %%
df1.groupby('year').max('average_price')
# Out:
#       average_price  houses_sold  no_of_crimes
# year
# 1995          53901      72640.0           NaN
# 1996          55755      93515.0           NaN
# 1997          61564     102709.0           NaN
# 1998          65743     103581.0           NaN
# 1999          75071     119652.0           NaN
# 2000          84191     105431.0           NaN
# 2001          95992     124849.0           NaN
# 2002         119982     132163.0           NaN
# 2003         138985     119798.0           NaN
# 2004         160330     126778.0           NaN
# 2005         167244     102289.0           NaN
# 2006         182031     120679.0           NaN
# 2007         194764     121246.0           NaN
# 2008         191750      62969.0           NaN
# 2009         174136      75376.0           NaN
# 2010         180807      64635.0           NaN
# 2011         177335      61631.0           NaN
# 2012         180129      62396.0           NaN
# 2013         188544      81041.0           NaN
# ...

# %%
df1.groupby('year').min('average_price')
# Out:
#       average_price  houses_sold  no_of_crimes
# year
# 1995          52788      47639.0           NaN
# 1996          52333      48694.0           NaN
# 1997          55789      66246.0           NaN
# 1998          61659      61036.0           NaN
# 1999          65522      59989.0           NaN
# 2000          75219      68031.0           NaN
# 2001          84245      64870.0           NaN
# 2002          96215      71678.0           NaN
# 2003         121610      75657.0           NaN
# 2004         139719      79540.0           NaN
# 2005         158572      53464.0           NaN
# 2006         166544      73019.0           NaN
# 2007         181824      79311.0           NaN
# 2008         165795      35029.0           NaN
# 2009         159340      25782.0           NaN
# 2010         174458      34383.0           NaN
# 2011         173046      36005.0           NaN
# 2012         174161      41395.0           NaN
# 2013         176816      41530.0           NaN
# ...

# %%
data.groupby('area').max('no_of_crimes')
# Out:
#                         average_price  houses_sold  no_of_crimes  year
# area
# barking and dagenham           305882        435.0        2049.0  2020
# barnet                         549401        891.0        2893.0  2020
# bexley                         347531        633.0        1914.0  2020
# brent                          519754        542.0        2937.0  2020
# bromley                        449293        870.0        2637.0  2020
# camden                         881212        446.0        4558.0  2020
# city of london                 939912        104.0          10.0  2020
# croydon                        378859        916.0        3263.0  2020
# ealing                         489687        678.0        3401.0  2020
# east midlands                  196534      12191.0           NaN  2020
# east of england                294035      15547.0           NaN  2020
# enfield                        404393        763.0        2798.0  2020
# ...

# %%
data.groupby('area').min('no_of_crimes')
# Out:
#                         average_price  houses_sold  no_of_crimes  year
# area
# barking and dagenham            50460         48.0        1217.0  1995
# barnet                          90107        139.0        1703.0  1995
# bexley                          63723         82.0         860.0  1995
# brent                           71307         58.0        1850.0  1995
# bromley                         81124        158.0        1441.0  1995
# camden                         115419         89.0        2079.0  1995
# city of london                  77101          2.0           0.0  1995
# croydon                         68006        142.0        2031.0  1995
# ealing                          79272         96.0        1871.0  1995
# east midlands                   44506       2245.0           NaN  1995
# east of england                 55033       3100.0           NaN  1995
# enfield                         70631         88.0        1635.0  1995
# ...

# %%
data[data['average_price'] < 100000]
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-01-02  city of london          82203  E09000001          7.0
# 2     1995-01-03  city of london          79121  E09000001         14.0
# 3     1995-01-04  city of london          77101  E09000001          7.0
# 4     1995-01-05  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13330 2001-01-11         england          95083  E92000001     109149.0
# 13331 2001-01-12         england          95992  E92000001      93329.0
# 13332 2002-01-01         england          96215  E92000001      71678.0
# 13333 2002-01-02         england          96676  E92000001      77131.0
# 13334 2002-01-03         england          98962  E92000001     102828.0
#
#        no_of_crimes  year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %%
data[data['average_price'] < 100000].value_counts('area')
# Out:
# area
# north east              112
# north west              111
# yorks and the humber    110
# east midlands            96
# west midlands            94
# england                  87
# barking and dagenham     85
# south west               78
# east of england          76
# newham                   72
# waltham forest           64
# bexley                   64
# lewisham                 62
# havering                 60
# south east               59
# greenwich                59
# croydon                  57
# enfield                  54
# sutton                   54
# hackney                  53
# redbridge                52
# southwark                48
# tower hamlets            47
# outer london             46
# hillingdon               44
# lambeth                  41
# hounslow                 41
# brent                    40
# london                   39
# merton                   35
# bromley                  33
# haringey                 33
# ealing                   31
# ...
